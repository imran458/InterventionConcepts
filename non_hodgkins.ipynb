# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e09afe9-644f-4fc0-85fb-ad4b034d7b67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e09afe9-644f-4fc0-85fb-ad4b034d7b67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nonhodgkins-intervention-concepts.csv to nonhodgkins-intervention-concepts.csv

# %%
df = pd.read_csv('nonhodgkins-intervention-concepts.csv')
df = df.replace(' ', '_', regex=True)
df.head()
# Out:
#                                               trial    intCUI  \
# 0  http://stjohns.edu/annoclinicaltrial/NCT00005590  C0282386
# 1  http://stjohns.edu/annoclinicaltrial/NCT00005590  C0282386
# 2  http://stjohns.edu/annoclinicaltrial/NCT00002578  C0010711
# 3  http://stjohns.edu/annoclinicaltrial/NCT00002578  C0010711
# 4  http://stjohns.edu/annoclinicaltrial/NCT00002578  C0061008
#
#               name  type
# 0     LEVOFLOXACIN  antb
# 1     LEVOFLOXACIN  orch
# 2       CYTARABINE  phsu
# 3       CYTARABINE  nnon
# 4  GALLIUM_NITRATE  phsu

# %%
types = ['phsu', 'topp', 'gngm', 'imft']
my_df = df.loc[df['type'].isin(types)]
names_count = my_df[['type','name']].groupby(['name','type']).size().reset_index(name='counts')
agg = names_count.groupby(['type','name']).agg({'counts':sum})
df_agg = agg['counts'].groupby('type', group_keys = False)
result = df_agg.apply(lambda x: x.sort_values(ascending=False).head(10))
result

# %%
words = [i for i in my_df['name'] if not isinstance(i, (int,float)) ]

# %%
from gensim import corpora
dictionary = corpora.Dictionary([words])
corpus = [dictionary.doc2bow(doc) for doc in [words]]

dictionary.token2id

import gensim
k= 4
topic_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, random_state=0,
                   chunksize=100,
                   alpha='auto',
                   per_word_topics=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
# !pip install pyLDAvis
# !pip install gensim

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
lda_vis = gensimvis.prepare(topic_model,corpus,dictionary,sort_topics=False)

pyLDAvis.display(lda_vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el591407107133340966177079619"></div>
# <script type="text/javascript">
#
# var ldavis_el591407107133340966177079619_data = {"mdsDat": {"x": [-0.013392616258906321, 0.00947299222065431, -5.4287878308848926e-05, 0.003973911916560859], "y": [7.369990005384737e-05, -0.0011309345516442241, -0.0018616284421965527, 0.0029188630937869295], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [99.97959654177926, 0.005796883060362878, 0.008308271637883526, 0.006298303522496556]}, "tinfo": {"Term": ["RITUXIMAB", "Cyclophosphamid", "ETOPOSIDE", "Peripheral_Blood_Stem_Cell_Transplantation", "PREDNISONE", "filgrastim", "CYTARABINE", "METHOTREXATE", "Antithymocyte_Globulin", "MELPHALAN", "Vincristine_sulphate", "FLUDARABINE_PHOSPHATE", "Busulphan", "FLUDARABINE", "RADIATION_THERAPY", "MYCOPHENOLATE_MOFETIL", "TOTAL_BODY_IRRADIATION", "DEXAMETHASONE", "TACROLIMUS", "Cyclosporin", "BRENTUXIMAB_VEDOTIN", "Bendamustin", "VINCRISTINE", "LENALIDOMIDE", "PLERIXAFOR", "Iphosphamide", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "CARMUSTINE", "OBINUTUZUMAB", "Zevalin", "PREDNISONE", "RITUXIMAB", "filgrastim", "BEVACIZUMAB", "Transplant", "Cyclophosphamid", "Autologous_Immunoglobulin_Idiotype-KLH_Conjugate_Vaccine", "DEXAMETHASONE", "Chemotherapy,_NOS", "R-CHOP", "CLOFARABINE", "APOLIZUMAB", "Autologous_Hematopoietic_Stem_Cell_Transplantation", "Iodine-131_Anti-B1_Antibody", "NIVOLUMAB", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "PLERIXAFOR", "Graft_Versus_Host_Disease_Prophylaxis/Therapy", "Nonmyeloablative_Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "TEMSIROLIMUS", "Allogeneic", "GM_CSF", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "THIOGUANINE", "MELPHALAN", "Stem_Cell_Transplant", "METHOTREXATE", "Thio-Tepa", "Therapeutic_Hydrocortisone", "UBLITUXIMAB", "ETOPOSIDE", "Peripheral_Blood_Stem_Cell_Transplantation", "CYTARABINE", "Antithymocyte_Globulin", "Vincristine_sulphate", "FLUDARABINE_PHOSPHATE", "FLUDARABINE", "RADIATION_THERAPY", "Busulphan", "MYCOPHENOLATE_MOFETIL", "TOTAL_BODY_IRRADIATION", "BRENTUXIMAB_VEDOTIN", "TACROLIMUS", "Bendamustin", "Cyclosporin", "VINCRISTINE", "LENALIDOMIDE", "Iphosphamide", "OBINUTUZUMAB", "CARMUSTINE", "Zevalin", "SR29142", "Nab-paclitaxel/Rituximab-coated_Nanoparticle_AR160", "Transfusion", "LMP2", "Chemotherapy_Regimen", "Carboxyamidotriazole", "Dendritic_Cell_Therapy", "Massage_therapy", "DACLATASVIR", "thrombospondin_1", "Fenretinide_Lipid_Matrix", "FOSCARNET_SODIUM", "PRT062070", "GRANULOCYTE-MACROPHAGE_COLONY-STIMULATING_FACTOR", "Pentamidin", "Pyridoxin", "Non-Myeloablative_Conditioning", "Aciclovir_sodium", "Cord_Blood_Transplantation", "LY2469298", "chemoradiation", "Whole_brain_radiation_therapy", "BETA_GLUCAN", "Acupuncture", "BGB-3111", "FORODESINE", "Allogeneic_bone_marrow_transplant", "Minocycline-EDTA", "RO5072759", "Stem_cell_harvesting", "ETOPOSIDE", "Peripheral_Blood_Stem_Cell_Transplantation", "Antithymocyte_Globulin", "CYTARABINE", "Busulphan", "Yttrium_Y_90_Monoclonal_Antibody_Lym-1", "MabThera", "KPT-9274", "Cyclosporin", "FLUDARABINE", "RADIATION_THERAPY", "BORTEZOMIB", "TACROLIMUS", "Zevalin", "TOTAL_BODY_IRRADIATION", "OBINUTUZUMAB", "RITUXIMAB", "MYCOPHENOLATE_MOFETIL", "Cyclophosphamid", "METHOTREXATE", "G_CSF", "Vincristine_sulphate", "ALEMTUZUMAB", "CARMUSTINE", "filgrastim", "Iphosphamide", "IBRITUMOMAB_TIUXETAN", "METHYLPREDNISOLONE", "OFATUMUMAB", "ALDESLEUKIN", "Bendamustin", "PREDNISONE", "MELPHALAN", "LENALIDOMIDE", "FLUDARABINE_PHOSPHATE", "DEXAMETHASONE", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "BRENTUXIMAB_VEDOTIN", "Fenretinide_Lipid_Matrix", "Nab-paclitaxel/Rituximab-coated_Nanoparticle_AR160", "Targretin", "RUCAPARIB", "NOSCAPINE", "Massage_therapy", "IMGN529", "Cord_Blood_Transplantation", "BAY59-8862", "Chemotherapy_Regimen", "FORODESINE", "chemoradiation", "ABP_798", "Acupuncture", "CDX", "DCDT2980S", "Tylenol", "LY317615", "Hyperbaric_Oxygen", "RevM10_Gene", "DA-EPOCH-R", "BETA_GLUCAN", "Allogeneic_Lymphocytes", "Transfusion", "Erwinia_Asparaginase", "SELUMETINIB", "Carboxyamidotriazole", "L_778, ...
