# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-524c9999-0b04-4ee0-8bcd-bced9274cf4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-524c9999-0b04-4ee0-8bcd-bced9274cf4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hodgkins-intervention-concepts.csv to hodgkins-intervention-concepts.csv

# %%
df = pd.read_csv('hodgkins-intervention-concepts.csv')
df = df.replace(' ', '_', regex=True)
df.head()
# Out:
#                                               trial    intCUI  \
# 0  http://stjohns.edu/annoclinicaltrial/NCT02332668  C3658706
# 1  http://stjohns.edu/annoclinicaltrial/NCT02332668  C3658706
# 2  http://stjohns.edu/annoclinicaltrial/NCT02332668  C3658706
# 3  http://stjohns.edu/annoclinicaltrial/NCT00619645  C1705576
# 4  http://stjohns.edu/annoclinicaltrial/NCT00619645  C0242602
#
#                                                 name  type
# 0                                      PEMBROLIZUMAB  imft
# 1                                      PEMBROLIZUMAB  phsu
# 2                                      PEMBROLIZUMAB  aapp
# 3  Allogeneic_Hematopoietic_Stem_Cell_Transplanta...  topp
# 4         Peripheral_Blood_Stem_Cell_Transplantation  topp

# %%
types = ['phsu', 'topp', 'gngm', 'imft']
my_df = df.loc[df['type'].isin(types)]
names_count = my_df[['type','name']].groupby(['name','type']).size().reset_index(name='counts')
agg = names_count.groupby(['type','name']).agg({'counts':sum})
df_agg = agg['counts'].groupby('type', group_keys = False)
result = df_agg.apply(lambda x: x.sort_values(ascending=False).head(10))
result
# Out:
# type  name
# gngm  filgrastim                                             75
#       sargramostim                                           15
#       ARM                                                     5
#       IL2                                                     3
#       FDG                                                     2
#       LMP2                                                    2
#       II                                                      2
#       WT1                                                     2
#       CT-2                                                    2
#       CELL                                                    2
# imft  BRENTUXIMAB_VEDOTIN                                    82
#       RITUXIMAB                                              62
#       Antithymocyte_Globulin                                 52
#       NIVOLUMAB                                              35
#       G_CSF                                                  31
#       PEMBROLIZUMAB                                          29
#       Therapeutic_Allogeneic_Lymphocytes                     25
#       ALEMTUZUMAB                                            18
#       PLERIXAFOR                                             14
#       CD30                                                   11
# phsu  Cyclophosphamid                                       188
#       ETOPOSIDE                                             110
#       MYCOPHENOLATE_MOFETIL                                  87
#       FLUDARABINE_PHOSPHATE                                  83
#       BRENTUXIMAB_VEDOTIN                                    82
#       Busulphan                                              79
#       TACROLIMUS                                             76
#       MELPHALAN                                              75
#       Cyclosporin                                            68
#       RITUXIMAB                                              62
# topp  Peripheral_Blood_Stem_Cell_Transplantation            110
#       RADIATION_THERAPY                                      78
#       TOTAL_BODY_IRRADIATION                                 76
#       Allogeneic_Hematopoietic_Stem_Cell_Transplantation     50
#       ALLOGENEIC_BONE_MARROW_TRANSPLANTATION                 40
#       ABVD                                                   34
#       Therapy                                                30
#       Chemotherapy,_NOS                                      26
#       Umbilical_Cord_Blood_Transplantation                   26
#       Infusion                                               25
# Name: counts, dtype: int64

# %%
words = [i for i in my_df['name'] if not isinstance(i, (int,float)) ]
words

# %%
from gensim import corpora
dictionary = corpora.Dictionary([words])
corpus = [dictionary.doc2bow(doc) for doc in [words]]

dictionary.token2id

import gensim
k= 3
topic_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, random_state=0,
                   chunksize=100,
                   alpha='auto',
                   per_word_topics=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
# !pip install pyLDAvis
# !pip install gensim

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
lda_vis = gensimvis.prepare(topic_model,corpus,dictionary,sort_topics=False)

pyLDAvis.display(lda_vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el59140582183484368388901692"></div>
# <script type="text/javascript">
#
# var ldavis_el59140582183484368388901692_data = {"mdsDat": {"x": [-0.0006839705267411474, -0.0035074931809097147, 0.004191463707650862], "y": [-0.0033068655419893917, 0.0020941025784806866, 0.0012127629635087006], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [39.335742715571136, 59.507335869993824, 1.1569214144350306]}, "tinfo": {"Term": ["Cyclophosphamid", "BRENTUXIMAB_VEDOTIN", "ETOPOSIDE", "MELPHALAN", "RITUXIMAB", "TOTAL_BODY_IRRADIATION", "MYCOPHENOLATE_MOFETIL", "Peripheral_Blood_Stem_Cell_Transplantation", "Busulphan", "Antithymocyte_Globulin", "NIVOLUMAB", "FLUDARABINE_PHOSPHATE", "TACROLIMUS", "RADIATION_THERAPY", "PEMBROLIZUMAB", "Cyclosporin", "filgrastim", "Decarbazine", "FLUDARABINE", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "METHOTREXATE", "Therapeutic_Allogeneic_Lymphocytes", "VINBLASTINE", "PREDNISONE", "ALEMTUZUMAB", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "ABVD", "Vincristine_sulphate", "CYTARABINE", "CARMUSTINE", "MYCOPHENOLATE_MOFETIL", "Adriamycin", "FLUDARABINE", "PEMBROLIZUMAB", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "PACLITAXEL", "Epoch", "Recombinant_Interleukin_11", "PREDNISOLONE", "Busulphan", "G_CSF", "Allogeneic_transplantation", "ADCT-301", "CBL0137", "Exercise_Intervention", "ALVOCIDIB", "CASPOFUNGIN_ACETATE", "VAMP", "Hodgkin's_Antigens-GM-CSF-Expressing_Cell_Vaccine", "Recombinant_Human_Stem_Cell_Factor", "HSCT", "Vidaza", "induction", "CAP", "SUCROSE", "Muromonab", "PROCARBAZINE", "Extracorporeal_Photopheresis", "IL-4", "IRATUMUMAB", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "Therapy", "METHOTREXATE", "ABVD", "FILGRASTIM", "VORINOSTAT", "LENALIDOMIDE", "IPILIMUMAB", "Peripheral_Blood_Stem_Cell_Transplantation", "VINCRISTINE", "BRENTUXIMAB_VEDOTIN", "DEXAMETHASONE", "Decarbazine", "ALDESLEUKIN", "PROCARBAZINE_HYDROCHLORIDE", "CD30", "GEMCITABINE_HYDROCHLORIDE", "Cyclophosphamid", "ETOPOSIDE", "Therapeutic_Allogeneic_Lymphocytes", "Cyclosporin", "Placebo", "Vincristine_sulphate", "FLUDARABINE_PHOSPHATE", "NIVOLUMAB", "Antithymocyte_Globulin", "PREDNISONE", "filgrastim", "MELPHALAN", "TOTAL_BODY_IRRADIATION", "TACROLIMUS", "RADIATION_THERAPY", "RITUXIMAB", "VINBLASTINE", "Chemotherapy,_NOS", "ALEMTUZUMAB", "Peg-filgrastim", "RITUXIMAB", "CYTARABINE", "EVEROLIMUS", "Infusion", "Thymoglobuline", "MK-8776", "Graft_Versus_Host_Disease_Prophylaxis/Therapy", "Iphosphamide", "Neupogen", "RADIATION_THERAPY", "BEACOPP", "ARA-C", "injection", "TACROLIMUS", "ARM", "Interferon", "ACALABRUTINIB", "CARMUSTINE", "IL2", "ALISERTIB", "Gamma-Secretase_Inhibitor_RO4929097", "ETHANOL", "TG-0054", "Ha", "Salvage_Therapy", "DOXIL", "Allogeneic_Epstein-Barr_Virus-Specific_Cytotoxic_T-Lymphocytes", "Monoclonal_Antibody_A27.15", "VINBLASTINE", "Antithymocyte_Globulin", "TOTAL_BODY_IRRADIATION", "filgrastim", "METHYLPREDNISOLONE", "ALEMTUZUMAB", "PLERIXAFOR", "FLUDARABINE_PHOSPHATE", "Cyclophosphamid", "MELPHALAN", "NIVOLUMAB", "ETOPOSIDE", "AVELUMAB", "PREDNISONE", "BRENTUXIMAB_VEDOTIN", "Cyclosporin", "Peripheral_Blood_Stem_Cell_Transplantation", "Therapeutic_Allogeneic_Lymphocytes", "GEMCITABINE", "Decarbazine", "Chemotherapy,_NOS", "METHOTREXATE", "Busulphan", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "MYCOPHENOLATE_MOFETIL", "FLUDARABINE", "PEMBROLIZUMAB", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "VORINOSTAT", "MELPHALAN", "ALVOCIDIB", "OBLIMERSEN_SODIUM", "L_778,123", "MELPHALAN_HYDROCHLORIDE", "ISOTRETINOIN", "parenteral_enteral_nutrition", "GALIXIMAB", "Iodine_I_131_Monoclonal_Antibody_BC8", "care/therapy,_supportive", "CAP", "EBV-Specific_Cytotoxic_T-Lymphocytes", "Conventional_Surgery", "INRT", "Recombinant_Interferon_Gamma", "MK-4280", "Musculoskeletal_Complications_Management", "TAA", "Vitamin_B12", "BMT", "Chemotherapy_Regimen", "GOSERELIN", "TOTAL_BODY_IRRADIATION", "APREPITANT", "DECITABINE", "GX15-070MS", "Morphine_sulphate", "Peptides", "NELFINAVIR", "CASPOFUNGIN_ACETATE", "Cyclophosphamid", "MESNA", "PACLITAXEL", "VINORELBINE", "MYCOPHENOLATE_MOFETIL", "PEM ...
