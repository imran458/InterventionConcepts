# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51c0ad62-9e31-4b9c-b775-10d7483d1d6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51c0ad62-9e31-4b9c-b775-10d7483d1d6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all-intervention-concepts.csv to all-intervention-concepts.csv

# %%
df = pd.read_csv('all-intervention-concepts.csv')
df = df.replace(' ', '_', regex=True)
df.head()
# Out:
#                                               trial    intCUI  \
# 0  http://stjohns.edu/annoclinicaltrial/NCT01756118  C2347425
# 1  http://stjohns.edu/annoclinicaltrial/NCT01492569  C0013794
# 2  http://stjohns.edu/annoclinicaltrial/NCT01492569  C0013794
# 3  http://stjohns.edu/annoclinicaltrial/NCT00089141  C0209368
# 4  http://stjohns.edu/annoclinicaltrial/NCT00089141  C0209368
#
#                          name  type
# 0                      BEZ235  phsu
# 1  Electroacupuncture_Therapy  topp
# 2  Electroacupuncture_Therapy  topp
# 3       MYCOPHENOLATE_MOFETIL  phsu
# 4       MYCOPHENOLATE_MOFETIL  orch

# %%
types = ['phsu', 'topp', 'gngm', 'imft']
my_df = df.loc[df['type'].isin(types)]
names_count = my_df[['type','name']].groupby(['name','type']).size().reset_index(name='counts')

# %%
agg = names_count.groupby(['type','name']).agg({'counts':sum})
df_agg = agg['counts'].groupby('type', group_keys = False)
result = df_agg.apply(lambda x: x.sort_values(ascending=False).head(10))
result
# Out:
# type  name
# gngm  filgrastim                                             43
#       sargramostim                                            8
#       ARM                                                     4
#       MUD                                                     3
#       MTX                                                     3
#       CTX                                                     2
#       WT1                                                     2
#       POST                                                    2
#       MSD                                                     2
#       CXCR-4                                                  1
# imft  RITUXIMAB                                              47
#       Antithymocyte_Globulin                                 33
#       BLINATUMOMAB                                           16
#       Therapeutic_Allogeneic_Lymphocytes                     15
#       G_CSF                                                  12
#       MOXETUMOMAB_PASUDOTOX                                  11
#       CAT-8015                                               10
#       INOTUZUMAB_OZOGAMICIN                                   9
#       ALEMTUZUMAB                                             8
#       ALDESLEUKIN                                             6
# phsu  Cyclophosphamid                                       165
#       METHOTREXATE                                          100
#       CYTARABINE                                             82
#       FLUDARABINE_PHOSPHATE                                  58
#       ETOPOSIDE                                              56
#       DEXAMETHASONE                                          54
#       Busulphan                                              51
#       TACROLIMUS                                             49
#       MYCOPHENOLATE_MOFETIL                                  48
#       RITUXIMAB                                              47
# topp  Peripheral_Blood_Stem_Cell_Transplantation             54
#       TOTAL_BODY_IRRADIATION                                 46
#       Allogeneic_Hematopoietic_Stem_Cell_Transplantation     43
#       RADIATION_THERAPY                                      37
#       ALLOGENEIC_BONE_MARROW_TRANSPLANTATION                 30
#       Umbilical_Cord_Blood_Transplantation                   19
#       Therapy                                                17
#       Infusion                                               15
#       Placebo                                                13
#       induction                                               8
# Name: counts, dtype: int64

# %%
words = [i for i in my_df['name'] if not isinstance(i, (int,float)) ]
words
# Out:
# ['BEZ235',
#  'Electroacupuncture_Therapy',
#  'Electroacupuncture_Therapy',
#  'MYCOPHENOLATE_MOFETIL',
#  'Placebo',
#  'ETOPOSIDE',
#  'Autologous_Hematopoietic_Stem_Cell_Transplantation',
#  'METHOTREXATE',
#  'DASATINIB',
#  'MERCAPTOPURINE',
#  'CYTARABINE',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Cyclophosphamid',
#  'DEXAMETHASONE',
#  'PREDNISONE',
#  'VINCRISTINE',
#  'MITOXANTRONE',
#  'Transcranial_Direct_Current_Stimulation',
#  'Brain_stimulation',
#  'S-HAM',
#  'SHAM',
#  'METHOTREXATE',
#  'ALEMTUZUMAB',
#  'ALEMTUZUMAB',
#  'MERCAPTOPURINE',
#  'Erwinase',
#  'Erwinia_Asparaginase',
#  'Exercise_Intervention',
#  'Dietary_Intervention',
#  'TOTAL_BODY_IRRADIATION',
#  'Mesenchymal_Stem_Cell_Transplantation',
#  'Cyclophosphamid',
#  'Umbilical_Cord_Blood_Transplantation',
#  'FLUDARABINE_PHOSPHATE',
#  'Cyclosporin',
#  'MYCOPHENOLATE_MOFETIL',
#  'LDE225',
#  'Iclusig',
#  'PONATINIB',
#  'Allogeneic_Stem_Cell_Transplantation',
#  'DARATUMUMAB',
#  'DARATUMUMAB',
#  'MMF',
#  'TACROLIMUS',
#  'sargramostim',
#  'INCB018424',
#  'Graft,_NOS',
#  'Cyclophosphamid',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Nonmyeloablative_Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'TACROLIMUS',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'METHOTREXATE',
#  'Busulphan',
#  'FLUDARABINE_PHOSPHATE',
#  'Tumour_therapy',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Induction_Therapy',
#  'induction',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'MYCOPHENOLATE_MOFETIL',
#  'filgrastim',
#  'Natural_Killer_Cell_Therapy',
#  'MELPHALAN',
#  'MYCOPHENOLATE_MOFETIL',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'LENALIDOMIDE',
#  'Umbilical_Cord_Blood_Transplantation',
#  'TACROLIMUS',
#  'FLUDARABINE_PHOSPHATE',
#  'Cyclophosphamid',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclophosphamid',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'TACROLIMUS',
#  'METHOTREXATE',
#  'RADIATION_THERAPY',
#  'filgrastim',
#  'Therapeutic_Immune_Globulin',
#  'Therapeutic_Immune_Globulin',
#  'sargramostim',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'METHOTREXATE',
#  'TACROLIMUS',
#  'Thio-Tepa',
#  'In_Vitro-Treated_Bone_Marrow_Transplantation',
#  'METHYLPREDNISOLONE',
#  'Cyclophosphamid',
#  'in_vitro-treated_peripheral_blood_stem_cell_transplantation',
#  'RADIATION_THERAPY',
#  'CYTARABINE',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'filgrastim',
#  'CYTARABINE',
#  'METHOTREXATE',
#  '6_mercaptopurine',
#  'DARATUMUMAB',
#  'DARATUMUMAB',
#  'CYTARABINE',
#  'Cyclophosphamid',
#  'VINCRISTINE',
#  'PREDNISONE',
#  'PEG-Asparaginase',
#  'Colony-stimulating_factor,_granulocyte',
#  'Total_Marrow_Irradiation',
#  'HLA',
#  'MYCOPHENOLATE_MOFETIL',
#  'Cyclosporin',
#  'Umbilical_Cord_Blood_Transplantation',
#  'Cyclophosphamid',
#  'FLUDARABINE',
#  'TOPOTECAN_HYDROCHLORIDE',
#  'EPZ-5676',
#  'LY2523355',
#  'SITAGLIPTIN',
#  'RAD001',
#  'PEGASPARGASE',
#  'Vincristine_sulphate',
#  'ETOPOSIDE',
#  'TOTAL_BODY_IRRADIATION',
#  'MERCAPTOPURINE',
#  'PALIFERMIN',
#  'METHOTREXATE',
#  'NELARABINE',
#  'Cyclophosphamid',
#  'FLUDARABINE_PHOSPHATE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'MELPHALAN',
#  'Imatinib_mesilate',
#  'CYTARABINE',
#  'MELPHALAN',
#  'Prophylactic',
#  'SOLUTION,_ISOTONIC',
#  'Maintenance_Therapy',
#  'induction',
#  'induction',
#  'M_NOS',
#  'FLUDARABINE',
#  'Cyclophosphamid',
#  'Chimeric_Antigen_Receptor_T-Cell_Therapy',
#  'TOCILIZUMAB',
#  'TOCILIZUMAB',
#  'PONATINIB',
#  'AP1903',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'ALDESLEUKIN',
#  'ALDESLEUKIN',
#  'ASPARAGINASE_ERWINIA_CHRYSANTHEMI',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Stem_Cell_Transplantation',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'CLOFARABINE',
#  'ALDESLEUKIN',
#  'ALDESLEUKIN',
#  'Transplant',
#  'CLOFARABINE',
#  'Gamma-Secretase_Inhibitor_RO4929097',
#  'DEXAMETHASONE',
#  'TH_302',
#  'PEGASPARGASE',
#  'Imatinib_mesilate',
#  'Vincristine_sulphate',
#  'PREDNISONE',
#  'CYTARABINE',
#  'VORINOSTAT',
#  'METHOTREXATE',
#  'DECITABINE',
#  'Therapy',
#  'HSCT',
#  'Regimen',
#  'Regimen',
#  'HSCT',
#  'Umbilical_Cord_Blood_Transplantation',
#  'Transplantation',
#  'Rabbit_ATG',
#  'Rabbit_ATG',
#  'MELPHALAN',
#  'FLUDARABINE',
#  'Transplant',
#  'CELL',
#  'HSCT',
#  'HPV,_quadrivalent',
#  'HPV,_quadrivalent',
#  'Vaccine',
#  'Vaccine',
#  'Gardasil',
#  'Gardasil',
#  'OFATUMUMAB',
#  'OFATUMUMAB',
#  'IBRUTINIB',
#  'NAVITOCLAX',
#  'METHOTREXATE',
#  'Cyclophosphamid',
#  'filgrastim',
#  'DEXAMETHASONE',
#  'CYTARABINE',
#  'Vincristine_sulphate',
#  'filgrastim',
#  'METHOTREXATE',
#  'NELARABINE',
#  'Cyclophosphamid',
#  'ETOPOSIDE',
#  'SAPANISERTIB',
#  'RALTITREXED',
#  'INOTUZUMAB_OZOGAMICIN',
#  'INOTUZUMAB_OZOGAMICIN',
#  'METHOTREXATE',
#  'OFATUMUMAB',
#  'OFATUMUMAB',
#  'Cyclophosphamid',
#  'DEXAMETHASONE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'CYTARABINE',
#  'Vincristine_sulphate',
#  'LEUCOVORIN_CALCIUM',
#  'PREDNISONE',
#  'MERCAPTOPURINE',
#  'VORINOSTAT',
#  'Cyclosporin',
#  'FLUDARABINE_PHOSPHATE',
#  'Colony-stimulating_factor,_granulocyte',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'METHOTREXATE',
#  'MYCOPHENOLATE_MOFETIL',
#  'Busulphan',
#  'TOTAL_BODY_IRRADIATION',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'TOPOTECAN_HYDROCHLORIDE',
#  'ETOPOSIDE',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'IPILIMUMAB',
#  'IPILIMUMAB',
#  'CALCIUM_CITRATE',
#  'VITAMIN_D',
#  'BU',
#  'Intervention',
#  'Therapy',
#  'Therapy',
#  'CYTARABINE',
#  'FLUDARABINE_PHOSPHATE',
#  'OBLIMERSEN_SODIUM',
#  'filgrastim',
#  'Therapy',
#  'G_CSF',
#  'Thymoglobuline',
#  'Thymoglobuline',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'FLUDARABINE',
#  'MELPHALAN',
#  'TACROLIMUS',
#  'FLUDARABINE',
#  'Cyclophosphamid',
#  'Natural_Killer_Cell_Therapy',
#  'vincristine_sulfate_liposomes',
#  'injection',
#  'Marqibo',
#  'M_Ab',
#  'VINCRISTINE',
#  'MAb',
#  'TOTAL_BODY_IRRADIATION',
#  'Thymoglobuline',
#  'Thymoglobuline',
#  'Busulphan',
#  'FLUDARABINE',
#  'CLOFARABINE',
#  'MITOXANTRONE',
#  'AHN-12',
#  'PEG-Asparaginase',
#  'PEG-Asparaginase',
#  'Cyclophosphamid',
#  'Iphosphamide',
#  'METHOTREXATE',
#  'Low-LET_Photon_Therapy',
#  'LEUCOVORIN_CALCIUM',
#  'DEXAMETHASONE',
#  'CYTARABINE',
#  'filgrastim',
#  'MESNA',
#  'Low-LET_Cobalt-60_Gamma_Ray_Therapy',
#  'Vincristine_sulphate',
#  'Cyclophosphamid',
#  'Therapeutic_Hydrocortisone',
#  'ETOPOSIDE',
#  'Donor_Lymphocyte_Infusion',
#  'Haploidentical_Stem_Cell_Transplantation',
#  'Radiation',
#  'Cyclophosphamid',
#  'Cyclophosphamid',
#  'Vincristine_sulphate',
#  'METHOTREXATE',
#  'RADIATION_THERAPY',
#  'filgrastim',
#  'LEUCOVORIN_CALCIUM',
#  'ETOPOSIDE',
#  'CYTARABINE',
#  'Iphosphamide',
#  'Vincristine_sulphate',
#  'PREDNISONE',
#  'Imatinib_mesilate',
#  'Therapy',
#  'Hematopoietic_Stem_Cell_Transplantation',
#  'Rabbit_anti-human_thymocyte_globulin',
#  'Rabbit_anti-human_thymocyte_globulin',
#  'PONATINIB',
#  'DEXAMETHASONE',
#  'DepoCyt',
#  'Therapy',
#  'Bronchoalveolar_Lavage',
#  'Therapy',
#  'Anti-CD123/CD3_Monoclonal_Antibody_MGD006',
#  'CALASPARGASE_PEGOL',
#  'Vincristine_sulphate',
#  'MERCAPTOPURINE',
#  'CYTARABINE',
#  'DEXAMETHASONE',
#  'Cyclophosphamid',
#  'PEGASPARGASE',
#  'CALASPARGASE_PEGOL',
#  'RADIATION_THERAPY',
#  'THIOGUANINE',
#  'METHOTREXATE',
#  'PREDNISONE',
#  'DEXAMETHASONE',
#  'Vincristine_sulphate',
#  'Cyclophosphamid',
#  'CYTARABINE',
#  'METHOTREXATE',
#  'PEGASPARGASE',
#  'METHYLPREDNISOLONE',
#  'Imatinib_mesilate',
#  'Drugs',
#  'FLUDARABINE_PHOSPHATE',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Cyclosporin',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'TOTAL_BODY_IRRADIATION',
#  'MYCOPHENOLATE_MOFETIL',
#  'OXALIPLATIN',
#  'ETOPOSIDE',
#  'Cyclosporin',
#  'METHOTREXATE',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'RADIATION_THERAPY',
#  'CYTARABINE',
#  'Cyclosporin',
#  'METHOTREXATE',
#  'FLUDARABINE_PHOSPHATE',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'MYCOPHENOLATE_MOFETIL',
#  'TIPIFARNIB',
#  'LENALIDOMIDE',
#  'FLUDARABINE_PHOSPHATE',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'ETOPOSIDE',
#  'Busulphan',
#  'MELPHALAN',
#  'TACROLIMUS',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclosporin',
#  'METHOTREXATE',
#  'MYCOPHENOLATE_MOFETIL',
#  'Cyclophosphamid',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'XmAb14045',
#  'AZD5991',
#  'MTX',
#  'MTX',
#  'Autologous',
#  'IMPACT',
#  'CD9',
#  'CD9',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'MELPHALAN',
#  'TOTAL_BODY_IRRADIATION',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'FLUDARABINE_PHOSPHATE',
#  'METHOTREXATE',
#  'FLUDARABINE',
#  'TACROLIMUS',
#  'Cyclophosphamid',
#  'TOTAL_BODY_IRRADIATION',
#  'LEUPROLIDE',
#  'Busulphan',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'FLT',
#  'Allogeneic_bone_marrow_transplant',
#  'ALVOCIDIB',
#  'CYTARABINE',
#  'MITOXANTRONE_HYDROCHLORIDE',
#  'Transplantation',
#  'Cell_Transplantation',
#  'PREDNISONE',
#  'Cyclophosphamid',
#  'METHOTREXATE',
#  'PREDNISOLONE',
#  'Vincristine_sulphate',
#  'MERCAPTOPURINE',
#  'RADIATION_THERAPY',
#  'DEXAMETHASONE',
#  'CYTARABINE',
#  'Imatinib_mesilate',
#  'HYDROCORTISONE_SODIUM_SUCCINATE',
#  'METHYLPREDNISOLONE',
#  'ETOPOSIDE_PHOSPHATE',
#  'PEGASPARGASE',
#  'Triapine',
#  'GEMCITABINE_HYDROCHLORIDE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'chemotherapy_combination',
#  'Exercise',
#  'VINCRISTINE',
#  'METHOTREXATE',
#  'Cyclophosphamid',
#  'EPIRUBICIN',
#  'E_coli_asparaginase',
#  'HYDROCORTISONE',
#  'CYTARABINE',
#  '6_mercaptopurine',
#  'PREDNISOLONE',
#  'MELPHALAN',
#  'TOTAL_BODY_IRRADIATION',
#  'filgrastim',
#  'FLUDARABINE_PHOSPHATE',
#  'TACROLIMUS',
#  'Cyclophosphamid',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Tyrosine_Kinase_Inhibitor',
#  'intravenous_administration',
#  'METHOTREXATE',
#  'VINCRISTINE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'THIOGUANINE',
#  'RUXOLITINIB',
#  'Cyclophosphamid',
#  'METHOTREXATE',
#  'CYTARABINE',
#  'DEXAMETHASONE',
#  'PEGASPARGASE',
#  'MERCAPTOPURINE',
#  'Administration',
#  'SITAGLIPTIN',
#  'PEGASPARGASE',
#  'CYTARABINE',
#  'CLADRIBINE',
#  'G_CSF',
#  'VELIPARIB',
#  'CARBOPLATIN',
#  'TOPOTECAN_HYDROCHLORIDE',
#  'ISOTRETINOIN',
#  'ENTINOSTAT',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'MYCOPHENOLATE_MOFETIL',
#  'FLUDARABINE_PHOSPHATE',
#  'Cyclosporin',
#  'Busulphan',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'BLINATUMOMAB',
#  'BLINATUMOMAB',
#  'DASATINIB',
#  'MYCOPHENOLATE_MOFETIL',
#  'FLUDARABINE_PHOSPHATE',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclosporin',
#  'Nonmyeloablative_Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'NILOTINIB',
#  'Imatinib_mesilate',
#  'Cyclophosphamid',
#  'FLUDARABINE',
#  'Leukopheresis',
#  'CMC-544',
#  'INOTUZUMAB',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Akt_Inhibitor_MK2206',
#  'CVAD',
#  'LEUCOVORIN_CALCIUM',
#  'Fluoro_Uracil',
#  'TOPOTECAN_HYDROCHLORIDE',
#  'DIET',
#  'VORINOSTAT',
#  'Liposomal_Cytarabine',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'LENALIDOMIDE',
#  'F-',
#  'Placebo',
#  'M_NOS',
#  'M_NOS',
#  'NILOTINIB',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclophosphamid',
#  'CLOFARABINE',
#  'TACROLIMUS',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'FILGRASTIM-SNDZ',
#  'FILGRASTIM-SNDZ',
#  'MYCOPHENOLATE_MOFETIL',
#  'FLUDARABINE',
#  'Umbilical_Cord_Blood_Transplantation',
#  'Busulphan',
#  'MELPHALAN',
#  'ALLOPURINOL',
#  'RASBURICASE',
#  'CARMUSTINE',
#  'ETOPOSIDE',
#  'CYTARABINE',
#  'MELPHALAN',
#  'Autologous_Hematopoietic_Stem_Cell_Transplantation',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'LENALIDOMIDE',
#  'INOTUZUMAB_OZOGAMICIN',
#  'INOTUZUMAB_OZOGAMICIN',
#  'BLINATUMOMAB',
#  'BLINATUMOMAB',
#  'ADCT-301',
#  'ADCT-301',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'FLUDARABINE_PHOSPHATE',
#  'Umbilical_Cord_Blood_Transplantation',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Umbilical_Cord_Blood_Transplantation',
#  'TOTAL_BODY_IRRADIATION',
#  'MYCOPHENOLATE_MOFETIL',
#  'TACROLIMUS',
#  'Cyclophosphamid',
#  'POSACONAZOLE',
#  'Allogeneic_Lymphocytes',
#  'Allogeneic_Lymphocytes',
#  'TOTAL_BODY_IRRADIATION',
#  'Irradiated',
#  'Thio-Tepa',
#  'METHYLPREDNISOLONE',
#  'FLUDARABINE',
#  'Busulphan',
#  'TACROLIMUS',
#  'MELPHALAN',
#  'Cyclophosphamid',
#  'ALEMTUZUMAB',
#  'ALEMTUZUMAB',
#  'DEXAMETHASONE',
#  'SELUMETINIB',
#  'FLUDARABINE',
#  'Cyclophosphamid',
#  'Infusion',
#  '6_mercaptopurine',
#  'ETOPOSIDE',
#  'PEGASPARGASE',
#  'Chidamide',
#  'CYTARABINE',
#  'Cyclophosphamid',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'IDARUBICIN',
#  'Adriamycin',
#  'DEXAMETHASONE',
#  'Injection,_intrathecal',
#  'VINCRISTINE',
#  'RADIATION_THERAPY',
#  'METHOTREXATE',
#  'Autologous',
#  'HSCT',
#  'BORTEZOMIB',
#  'CLOFARABINE',
#  'Traumeel_S',
#  'Placebo',
#  'NILOTINIB',
#  'GEMCITABINE_HYDROCHLORIDE',
#  'RADIATION_THERAPY',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Cyclophosphamid',
#  'TACROLIMUS',
#  'FLUDARABINE_PHOSPHATE',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Busulphan',
#  'METHOTREXATE',
#  'Rabbit_antithymocyte_globulin',
#  'Rabbit_antithymocyte_globulin',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'CHLORAMBUCIL',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'ETOPOSIDE',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Cyclophosphamid',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Tomotherapy',
#  'INTENSITY-MODULATED_RADIATION_THERAPY',
#  'Busulphan',
#  'FLUDARABINE_PHOSPHATE',
#  'Cyclophosphamid',
#  'TOTAL_BODY_IRRADIATION',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Cyclosporin',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Induction_Therapy',
#  'Cyclophosphamid',
#  'Graft,_NOS',
#  'FLUDARABINE_PHOSPHATE',
#  'METHOTREXATE',
#  'ALEMTUZUMAB',
#  'ALEMTUZUMAB',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'TACROLIMUS',
#  'Busulphan',
#  'induction',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Tumour_therapy',
#  'LEUCOVORIN_CALCIUM',
#  'TRIMETREXATE_GLUCURONATE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'MELPHALAN',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'FLUDARABINE_PHOSPHATE',
#  'ETOPOSIDE',
#  'Busulphan',
#  'CARMUSTINE',
#  'CYTARABINE',
#  'Cyclophosphamid',
#  'TOTAL_BODY_IRRADIATION',
#  'ALLOPURINOL',
#  'Leukovorin',
#  'METHOTREXATE',
#  'MERCAPTOPURINE',
#  'MITOXANTRONE',
#  'PREDNISONE',
#  'ASPARAGINASE',
#  'Cyclophosphamid',
#  'filgrastim',
#  'THIOGUANINE',
#  'CYTARABINE',
#  'DEXAMETHASONE',
#  'VINCRISTINE',
#  'RADIATION_THERAPY',
#  'Bactrim',
#  'LMB-2_Immunotoxin',
#  'LMB-2_Immunotoxin',
#  'SUCROSE',
#  'SODIUM_FERRIC_GLUCONATE_COMPLEX',
#  'DARBEPOETIN_ALFA',
#  'Ferrous_sulphate',
#  'Placebo',
#  'anti-CD22_immunotoxin',
#  'anti-CD22_immunotoxin',
#  'MERCAPTOPURINE',
#  'METHOTREXATE',
#  'MITOXANTRONE',
#  'VORINOSTAT',
#  'DEXAMETHASONE',
#  'CYTARABINE',
#  'BORTEZOMIB',
#  'PEG-L-Asparaginase',
#  'Erwinia_L-asparaginase',
#  'HYDROCORTISONE',
#  'Erwinase',
#  'DASATINIB',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'Cyclosporin',
#  'Cyclophosphamid',
#  'filgrastim',
#  'Busulphan',
#  'RADIATION_THERAPY',
#  'METHYLPREDNISOLONE',
#  'Umbilical_Cord_Blood_Transplantation',
#  'Bone_Marrow_Transplantation',
#  'Chemotherapy,_NOS',
#  'Cyclophosphamid',
#  'Peripheral_Blood_Lymphocyte_Therapy',
#  'METHYLPREDNISOLONE',
#  'Biological_Therapy',
#  'RADIATION_THERAPY',
#  'FLUDARABINE_PHOSPHATE',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Cyclosporin',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Non-Specific_Immune-Modulator_Therapy',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Thio-Tepa',
#  'Leukocyte_Therapy',
#  'METHOTREXATE',
#  'ASPARAGINASE',
#  'filgrastim',
#  'Vincristine_sulphate',
#  'LEUCOVORIN_CALCIUM',
#  'PEGASPARGASE',
#  'Imatinib_mesilate',
#  'Therapeutic_Hydrocortisone',
#  'ETOPOSIDE',
#  'Cyclophosphamid',
#  'CYTARABINE',
#  'PREDNISONE',
#  'MYCOPHENOLATE_MOFETIL',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'BU',
#  'Yttrium_Y_90_Anti-CD19_Monoclonal_Antibody_BU12',
#  'Phosphate_Buffer',
#  'DASATINIB',
#  'Placebo',
#  'ASPARAGINASE',
#  'METHOTREXATE',
#  'PREDNISONE',
#  'MERCAPTOPURINE',
#  'Cyclophosphamid',
#  'CYTARABINE',
#  'VINCRISTINE',
#  'Treatment',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'DEXAMETHASONE',
#  'LENALIDOMIDE',
#  'MYCOPHENOLATE_MOFETIL',
#  'FLUDARABINE_PHOSPHATE',
#  'TACROLIMUS',
#  'RADIATION_THERAPY',
#  'Cyclophosphamid',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Cyclophosphamid',
#  'CART-19_Cells',
#  'FLUDARABINE',
#  'NELARABINE',
#  'HYDROCORTISONE',
#  'PREDNISONE',
#  'EZN_3042',
#  'PEG-Asparaginase',
#  'VINCRISTINE',
#  'METHOTREXATE',
#  'CYTARABINE',
#  'HLA',
#  'MUD',
#  'Stem_Cell_Transplantation',
#  'Stem_Cell_Transplantation',
#  'DEXRAZOXANE_HYDROCHLORIDE',
#  'ETOPOSIDE',
#  'PEGASPARGASE',
#  'CYTARABINE',
#  'METHOTREXATE',
#  'PREDNISONE',
#  'L-Asparaginase',
#  'Therapeutic_Hydrocortisone',
#  'Vincristine_sulphate',
#  'filgrastim',
#  'LEUCOVORIN_CALCIUM',
#  'EPRATUZUMAB',
#  'Cyclophosphamid',
#  'TTI-621',
#  'TTI-621',
#  'TTI-621',
#  'TTI-621',
#  'TTI-621',
#  'TTI-621',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'NIVOLUMAB',
#  'NIVOLUMAB',
#  'BASILIXIMAB',
#  'BASILIXIMAB',
#  'RUXOLITINIB',
#  'PREDNISONE',
#  'VINCRISTINE',
#  'DECITABINE',
#  'ETOPOSIDE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'TOTAL_BODY_IRRADIATION',
#  'TOTAL_BODY_IRRADIATION',
#  'Busulphan',
#  'FLUDARABINE',
#  'MYCOPHENOLATE_MOFETIL',
#  'MELPHALAN',
#  'TACROLIMUS',
#  'Infusion',
#  'CLOFARABINE',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'FLUDARABINE_PHOSPHATE',
#  'METHOTREXATE',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'MELPHALAN',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'filgrastim',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Cyclosporin',
#  'DIET',
#  'VENETOCLAX',
#  'VINCRISTINE',
#  'CARBOPLATIN',
#  'Amifostine_Trihydrate',
#  'Cyclophosphamid',
#  'sargramostim',
#  'METHOTREXATE',
#  'PEGASPARGASE',
#  'CYTARABINE',
#  'VINCRISTINE',
#  'MITOXANTRONE',
#  'VELCADE',
#  'METHOTREXATE',
#  'HYDROCORTISONE',
#  'DEXAMETHASONE',
#  'Cyclophosphamid',
#  'CLOFARABINE',
#  'IMGN632',
#  'IMGN632',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Cyclophosphamid',
#  'Infusion',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclosporin',
#  'Umbilical_Cord_Blood_Transplantation',
#  'MYCOPHENOLATE_MOFETIL',
#  'FLUDARABINE_PHOSPHATE',
#  'ETOPOSIDE',
#  'CLOFARABINE',
#  'Cyclophosphamid',
#  'RADIATION_THERAPY',
#  'Transfusion',
#  'CYTARABINE',
#  'Busulphan',
#  'Cyclophosphamid',
#  'ETOPOSIDE',
#  'T-Cell_Depletion',
#  'Therapy',
#  'Intervention',
#  'Vincristine_sulphate',
#  'METHOTREXATE',
#  'MERCAPTOPURINE',
#  'PEGASPARGASE',
#  'PREDNISONE',
#  'DEXAMETHASONE',
#  'Prophylactic_Cranial_Irradiation',
#  'Cyclophosphamid',
#  'THIOGUANINE',
#  'CYTARABINE',
#  'DASATINIB',
#  'Chemotherapy,_NOS',
#  'VENETOCLAX',
#  'Busulphan',
#  'MYCOPHENOLATE_MOFETIL',
#  'Cyclophosphamid',
#  'TOTAL_BODY_IRRADIATION',
#  'MESNA',
#  'MESNA',
#  'TOTAL_BODY_IRRADIATION',
#  'Cyclophosphamid',
#  'POST',
#  'FLUDARABINE',
#  'Cyclophosphamid',
#  'POST',
#  'MESNA',
#  'G_CSF',
#  'Cyclophosphamid',
#  'MESNA',
#  'Infusion',
#  'HYDROCORTISONE_SODIUM_SUCCINATE',
#  'PREDNISONE',
#  'ETOPOSIDE',
#  'LEUCOVORIN_CALCIUM',
#  'RASBURICASE',
#  'CYTARABINE',
#  'Vincristine_sulphate',
#  'filgrastim',
#  'METHYLPREDNISOLONE',
#  'Cyclophosphamid',
#  'RITUXIMAB',
#  'RITUXIMAB',
#  'METHOTREXATE',
#  'VINCRISTINE',
#  'METHOTREXATE',
#  'MERCAPTOPURINE',
#  'CYTARABINE',
#  'Cyclophosphamid',
#  'Autologous_Anti-CD19CAR-4-1BB-CD3zeta-EGFRt-expressing_T_Lymphocytes',
#  'VOLASERTIB',
#  'Vincristine_sulphate_liposome',
#  'VP16',
#  'VP16',
#  'Treosulphan',
#  'OKT3',
#  'OKT3',
#  'Thio-Tepa',
#  'FLUDARABINE',
#  'VP16',
#  'VINCRISTINE',
#  'METHOTREXATE',
#  'RAD001',
#  'Cyclophosphamid',
#  'DEXAMETHASONE',
#  'CYTARABINE',
#  'Methylprednisone',
#  'G_CSF',
#  'ARA-C',
#  'MESNA',
#  'EVEROLIMUS',
#  'Therapy',
#  'Cyclosporin',
#  'Allogeneic_Hematopoietic_Stem_Cell_Transplantation',
#  'Cyclophosphamid',
#  'Umbilical_Cord_Blood_Transplantation',
#  'MYCOPHENOLATE_MOFETIL',
#  'TOTAL_BODY_IRRADIATION',
#  'FLUDARABINE_PHOSPHATE',
#  'TL32711',
#  'Antithymocyte_Globulin',
#  'Antithymocyte_Globulin',
#  'ALLOGENEIC_BONE_MARROW_TRANSPLANTATION',
#  'Cyclophosphamid',
#  'RADIATION_THERAPY',
#  'Busulphan',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'Cyclosporin',
#  'METHOTREXATE',
#  'Intrathecal_Chemotherapy',
#  '9-AC',
#  '9-AMINOCAMPTOTHECIN',
#  'DECITABINE',
#  'BLINATUMOMAB',
#  'BLINATUMOMAB',
#  'FLUDARABINE',
#  'Cyclophosphamid',
#  'Imatinib_mesilate',
#  'RISEDRONATE',
#  'VITAMIN_D',
#  'Actonel',
#  'Pyroxamide',
#  'FTS',
#  'Peptide',
#  'RIMIDUCID',
#  'Interleukin-2',
#  'FLUDARABINE',
#  'EPRATUZUMAB',
#  'MESNA',
#  'Infusion',
#  'Cyclophosphamid',
#  'Low-LET_Photon_Therapy',
#  'Low-LET_Electron_Therapy',
#  'filgrastim',
#  'Peripheral_Blood_Stem_Cell_Transplantation',
#  'ETOPOSIDE',
#  'EPRATUZUMAB',
#  'EPRATUZUMAB',
#  'filgrastim',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Therapeutic_Allogeneic_Lymphocytes',
#  'Cyclophosphamid',
#  'ETOPOSIDE',
#  'BLINATUMOMAB',
#  'BLINATUMOMAB',
#  'DASATINIB',
#  'ASPARAGINASE',
#  'Cyclophosphamid',
#  'LEUCOVORIN_CALCIUM',
#  'THIOGUANINE',
#  'PREDNISONE',
#  'Vincristine_sulphate',
#  'METHOTREXATE',
#  'CYTARABINE',
#  'MERCAPTOPURINE',
#  'DEXAMETHASONE',
#  'RADIATION_THERAPY',
#  'EM-1421',
#  ...]

# %%
from gensim import corpora
dictionary = corpora.Dictionary([words])
corpus = [dictionary.doc2bow(doc) for doc in [words]]

dictionary.token2id

import gensim
k= 4
topic_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, random_state=0,
                   chunksize=100,
                   alpha='auto',
                   per_word_topics=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
# !pip install pyLDAvis
# !pip install gensim

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
lda_vis = gensimvis.prepare(topic_model,corpus,dictionary,sort_topics=False)

pyLDAvis.display(lda_vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el621402557968292647246305883"></div>
# <script type="text/javascript">
#
# var ldavis_el621402557968292647246305883_data = {"mdsDat": {"x": [0.008084129343161111, -0.0009377139520995162, -0.0015728938672576777, -0.005573521523803917], "y": [-0.00017241503743147438, -0.0015342545576434157, 0.0023664519904039887, -0.0006597823953291029], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [0.019779745124464367, 3.9040790864321724, 3.428646757962301, 92.64749441048106]}, "tinfo": {"Term": ["Cyclophosphamid", "RITUXIMAB", "METHOTREXATE", "CYTARABINE", "Antithymocyte_Globulin", "Busulphan", "FLUDARABINE_PHOSPHATE", "Peripheral_Blood_Stem_Cell_Transplantation", "TACROLIMUS", "ETOPOSIDE", "DEXAMETHASONE", "MYCOPHENOLATE_MOFETIL", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "FLUDARABINE", "TOTAL_BODY_IRRADIATION", "Cyclosporin", "MELPHALAN", "filgrastim", "RADIATION_THERAPY", "PREDNISONE", "VINCRISTINE", "Vincristine_sulphate", "CLOFARABINE", "Therapeutic_Allogeneic_Lymphocytes", "BLINATUMOMAB", "MERCAPTOPURINE", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "PEGASPARGASE", "LEUCOVORIN_CALCIUM", "MOXETUMOMAB_PASUDOTOX", "SODIUM_FERRIC_GLUCONATE_COMPLEX", "DepoCyt", "Fluorothymidine", "VOLASERTIB", "BEZ235", "ACALABRUTINIB", "Recombinant_Interferon_Alfa", "INCB018424", "MIDOSTAURIN", "CRYOTHERAPY", "Oncaspar", "in_vitro-treated_peripheral_blood_stem_cell_transplantation", "Recombinant_EphB4-HSA_Fusion_Protein", "LY2523355", "Peripheral_blood_stem_cell_Transplant", "SELUMETINIB", "Autologous_Anti-CD19CAR-4-1BB-CD3zeta-EGFRt-expressing_T_Lymphocytes", "RISEDRONATE", "Erwinaze", "LDE225", "CELL", "FTS", "Allogeneic_hematopoietic_stem_cell_transplant", "Hydrochloride,_Ondansetron", "RALTITREXED", "INSULIN_GLARGINE", "LEUPROLIDE", "CLADRIBINE", "Fluoro_Uracil", "CXCR4", "Genome", "Busulphan", "METHOTREXATE", "Bendamustin", "Liposomal_Cytarabine", "PREDNISONE", "RITUXIMAB", "Imatinib_mesilate", "6_mercaptopurine", "ENTINOSTAT", "VENETOCLAX", "Total_Marrow_Irradiation", "VINCRISTINE", "CLOFARABINE", "Antithymocyte_Globulin", "MYCOPHENOLATE_MOFETIL", "Cyclosporin", "DASATINIB", "ALEMTUZUMAB", "Cyclophosphamid", "INOTUZUMAB_OZOGAMICIN", "LEUCOVORIN_CALCIUM", "CYTARABINE", "TACROLIMUS", "BORTEZOMIB", "MOXETUMOMAB_PASUDOTOX", "VP16", "FLUDARABINE_PHOSPHATE", "ETOPOSIDE", "FLUDARABINE", "TOTAL_BODY_IRRADIATION", "Transplant", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "Therapeutic_Allogeneic_Lymphocytes", "MELPHALAN", "Thio-Tepa", "filgrastim", "Peripheral_Blood_Stem_Cell_Transplantation", "DEXAMETHASONE", "MERCAPTOPURINE", "RADIATION_THERAPY", "BLINATUMOMAB", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "Vincristine_sulphate", "PEGASPARGASE", "TCR_Alpha-Beta", "VOLASERTIB", "ALEMTUZUMAB", "MIDOSTAURIN", "GO", "ACALABRUTINIB", "DEXTROMETHORPHAN_HYDROBROMIDE", "filgrastim", "CARBOPLATIN", "LY2523355", "Peg-filgrastim", "DepoCyt", "ENTINOSTAT", "Fenretinimide", "Liposomal_Cytarabine", "Graft_Versus_Host_Disease_Prophylaxis/Therapy", "Peripheral_blood_stem_cell_Transplant", "VORICONAZOLE", "OBLIMERSEN_SODIUM", "Intervention,_Educational", "PACLITAXEL", "Hydrochloride,_Ondansetron", "SODIUM_FERRIC_GLUCONATE_COMPLEX", "Gamma-Secretase_Inhibitor_RO4929097", "TIPIFARNIB", "Fluorothymidine", "Recombinant_Interferon_Alfa", "FTS", "Methylprednisone", "in_vitro-treated_peripheral_blood_stem_cell_transplantation", "Transplant", "ALLOGENEIC_BONE_MARROW_TRANSPLANTATION", "NILOTINIB", "DARATUMUMAB", "PREDNISONE", "ASPARAGINASE", "METHOTREXATE", "ETOPOSIDE", "BORTEZOMIB", "MYCOPHENOLATE_MOFETIL", "Cyclophosphamid", "Thio-Tepa", "RITUXIMAB", "MELPHALAN", "Infusion", "Imatinib_mesilate", "TOTAL_BODY_IRRADIATION", "Busulphan", "MOXETUMOMAB_PASUDOTOX", "MERCAPTOPURINE", "MESNA", "FLUDARABINE_PHOSPHATE", "BLINATUMOMAB", "FLUDARABINE", "Therapeutic_Allogeneic_Lymphocytes", "Antithymocyte_Globulin", "CLOFARABINE", "TACROLIMUS", "Umbilical_Cord_Blood_Transplantation", "Vincristine_sulphate", "Cyclosporin", "CYTARABINE", "DEXAMETHASONE", "Allogeneic_Hematopoietic_Stem_Cell_Transplantation", "RADIATION_THERAPY", "VINCRISTINE",  ...
